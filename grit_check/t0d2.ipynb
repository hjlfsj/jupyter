// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/grit/t0d2_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : crush                                                  *
// *Entries : 183445363 : Total =      3852688127 bytes  File  Size = 1485030005 *
// *        :          : Tree compression factor =   2.59                       *
// ******************************************************************************
// *Br    0 :side      : side/I                                                 *
// *Entries :183445363 : Total  Size=  733846090 bytes  File Size  =   51748878 *
// *Baskets :      707 : Basket Size=    3047936 bytes  Compression=  14.18     *
// *............................................................................*
// *Br    1 :strip     : strip/I                                                *
// *Entries :183445363 : Total  Size=  733846801 bytes  File Size  =  135806288 *
// *Baskets :      707 : Basket Size=    3047936 bytes  Compression=   5.40     *
// ...

// %%
tree->Draw("strip>>(64,0,64)","side==0");
c1->Draw();
// Out:
// <div id="root_plot_1782882364589" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782882364589() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21960,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782882364589', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("strip>>(64,0,64)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1782882388178" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782882388178() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(22024,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782882388178', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e>>(7000,0,70000)","side==0");
c1->Draw();
// Out:
// <div id="root_plot_1782882405404" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782882405404() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(55269,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782882405404', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e>>(7000,0,70000)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1782882416535" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782882416535() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(53962,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782882416535', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("strip>>(64,0,64)","side==0");
c1->Draw();
