// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/grit/t0d1_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : crush                                                  *
// *Entries : 275936145 : Total =      5795126040 bytes  File  Size = 1761340420 *
// *        :          : Tree compression factor =   3.29                       *
// ******************************************************************************
// *Br    0 :side      : side/I                                                 *
// *Entries :275936145 : Total  Size= 1103834880 bytes  File Size  =   68546888 *
// *Baskets :      989 : Basket Size=    3047936 bytes  Compression=  16.10     *
// *............................................................................*
// *Br    1 :strip     : strip/I                                                *
// *Entries :275936145 : Total  Size= 1103835965 bytes  File Size  =  156411303 *
// *Baskets :      990 : Basket Size=    3047936 bytes  Compression=   7.06     *
// *............................................................................*
// *Br    2 :energy    : e/I                                                    *
// *Entries :275936145 : Total  Size= 1103836944 bytes  File Size  =  361416844 *
// *Baskets :      990 : Basket Size=    3047936 bytes  Compression=   3.05     *
// *............................................................................*
// *Br    3 :time      : t/D                                                    *
// *Entries :275936145 : Total  Size= 2207631784 bytes  File Size  = 1164353493 *
// *Baskets :     1564 : Basket Size=    6095360 bytes  Compression=   1.90     *
// *............................................................................*
// *Br    4 :cv        : cv/O                                                   *
// *Entries :275936145 : Total  Size=  275986094 bytes  File Size  =   10560307 *
// *Baskets :      558 : Basket Size=     761856 bytes  Compression=  26.13     *
// *............................................................................*

// %%
tree->Draw("strip>>(32,0,32)","side==0");
// Out:
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %%
c1->Draw();
// Out:
// <div id="root_plot_1782874491771" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782874491771() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21830,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782874491771', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1782874491771();
// </script>

// %%
tree->Draw("strip>>(32,0,32)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1782874615674" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782874615674() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21833,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782874615674', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1782874615674();
// </script>

// %%
tree->Draw("e>>(5000,0,70000)","side==0");
c1->Draw();
// Out:
// <div id="root_plot_1782874748076" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782874748076() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(40195,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782874748076', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1782874748076();
// </script>

// %%
tree->Draw("e>>(5000,0,70000)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1782874761081" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782874761081() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(41853,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782874761081', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1782874761081();
// </script>

// %%
tree->Draw("e>>(5000,0,5000)","side==0");
c1->Draw();
// Out:
// <div id="root_plot_1782874980406" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782874980406() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(42483,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782874980406', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1782874980406();
// </script>

// %%
tree->Draw("e>>(5000,0,5000)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1782874993429" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782874993429() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(38138,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782874993429', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1782874993429();
// </script>

// %%
tree->Draw("e>>(5000,0,5000)","side==0&&strip==0");
c1->Draw();
// Out:
// <div id="root_plot_1782878420629" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782878420629() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(30156,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782878420629', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1782878420629();
// </script>

// %%
tree->Draw("e>>(5000,0,5000)","side==0&&strip==1");
c1->Draw();
// Out:
// <div id="root_plot_1782878463480" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782878463480() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(30654,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782878463480', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1782878463480();
// </script>

// %%
tree->Draw("strip>>(32,0,32)","side==0&&e>150");
c1->Draw();
// Out:
// <div id="root_plot_1783082614828" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783082614828() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21793,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783082614828', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783082614828();
// </script>

// %%
tree->Draw("strip>>(32,0,32)","side==1&&e>450");
c1->Draw();
// Out:
// <div id="root_plot_1783082629741" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783082629741() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21790,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783082629741', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783082629741();
// </script>
