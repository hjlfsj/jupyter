// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/grit/t0d3_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : crush                                                  *
// *Entries : 169619920 : Total =      3562342682 bytes  File  Size = 1384772204 *
// *        :          : Tree compression factor =   2.57                       *
// ******************************************************************************
// *Br    0 :side      : side/I                                                 *
// *Entries :169619920 : Total  Size=  678542134 bytes  File Size  =   61023338 *
// *Baskets :      683 : Basket Size=    3047936 bytes  Compression=  11.12     *
// *............................................................................*
// *Br    1 :strip     : strip/I                                                *
// *Entries :169619920 : Total  Size=  678542821 bytes  File Size  =  123567713 *
// *Baskets :      683 : Basket Size=    3047936 bytes  Compression=   5.49     *
// *............................................................................*
// *Br    2 :energy    : e/I                                                    *
// *Entries :169619920 : Total  Size=  678543493 bytes  File Size  =  356042437 *
// *Baskets :      683 : Basket Size=    3047936 bytes  Compression=   1.91     *
// *............................................................................*
// *Br    3 :time      : t/D                                                    *
// *Entries :169619920 : Total  Size= 1357063127 bytes  File Size  =  822472072 *
// *Baskets :     1137 : Basket Size=    6095360 bytes  Compression=   1.65     *
// *............................................................................*
// *Br    4 :cv        : cv/O                                                   *
// *Entries :169619920 : Total  Size=  169650734 bytes  File Size  =   21631098 *
// *Baskets :      343 : Basket Size=     761856 bytes  Compression=   7.84     *
// *............................................................................*

// %%
tree->Draw("strip>>(32,0,32)","side==0");
// Out:
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %%
c1->Draw();
// Out:
// <div id="root_plot_1783083804793" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783083804793() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21835,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783083804793', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783083804793();
// </script>

// %%
tree->Draw("strip>>(32,0,32)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1783083812457" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783083812457() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21804,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783083812457', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783083812457();
// </script>

// %%
tree->Draw("e>>(5000,0,70000)","side==0");
c1->Draw();
// Out:
// <div id="root_plot_1783083825155" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783083825155() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(45310,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783083825155', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783083825155();
// </script>

// %%
tree->Draw("e>>(5000,0,70000)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1783083834578" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783083834578() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(45564,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783083834578', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783083834578();
// </script>

// %%
tree->Draw("e>>(5000,0,5000)","side==0");
c1->Draw();
// Out:
// <div id="root_plot_1783083844980" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783083844980() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(42886,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783083844980', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783083844980();
// </script>

// %%
tree->Draw("e>>(5000,0,5000)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1783083854512" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783083854512() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(44030,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783083854512', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783083854512();
// </script>

// %%
tree->Draw("e>>(5000,0,5000)","side==0&&strip==0");
c1->Draw();
// Out:
// <div id="root_plot_1783083865859" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783083865859() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(31111,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783083865859', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783083865859();
// </script>

// %%
tree->Draw("e>>(5000,0,5000)","side==0&&strip==1");
c1->Draw();
// Out:
// <div id="root_plot_1783083877100" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783083877100() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(31246,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783083877100', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783083877100();
// </script>

// %%
tree->Draw("strip>>(32,0,32)","side==1&&e>150");
c1->Draw();
// Out:
// <div id="root_plot_1783084158559" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783084158559() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21798,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783084158559', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783084158559();
// </script>

// %%
tree->Draw("strip>>(32,0,32)","side==0&&e>150");
c1->Draw();
// Out:
// <div id="root_plot_1783084288287" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783084288287() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21808,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783084288287', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783084288287();
// </script>
