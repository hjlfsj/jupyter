// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/grit/t0d4_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : crush                                                  *
// *Entries : 245884983 : Total =      5164050853 bytes  File  Size = 1310568872 *
// *        :          : Tree compression factor =   3.94                       *
// ******************************************************************************
// *Br    0 :side      : side/I                                                 *
// *Entries :245884983 : Total  Size=  983629686 bytes  File Size  =   25193768 *
// *Baskets :      983 : Basket Size=    3047936 bytes  Compression=  39.04     *
// *............................................................................*
// *Br    1 :strip     : strip/I                                                *
// *Entries :245884983 : Total  Size=  983630673 bytes  File Size  =   45186188 *
// *Baskets :      983 : Basket Size=    3047936 bytes  Compression=  21.77     *
// ...

// %%
tree->Draw("strip>>(32,0,32)","side==0");

// %%
c1->Draw();
// Out:
// <div id="root_plot_1782884148594" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782884148594() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21821,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782884148594', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("strip>>(32,0,32)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1782884159005" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782884159005() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21842,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782884159005', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e>>(5000,0,70000)","side==0");
c1->Draw();
// Out:
// <div id="root_plot_1782884168013" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782884168013() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(29983,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782884168013', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e>>(5000,0,70000)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1782884179831" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782884179831() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(30184,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782884179831', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e>>(5000,0,5000)","side==0");
c1->Draw();
// Out:
// <div id="root_plot_1782884188872" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782884188872() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(39474,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782884188872', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e>>(5000,0,5000)","side==1");
c1->Draw();
// Out:
// <div id="root_plot_1782884200806" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782884200806() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(39631,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782884200806', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e>>(5000,0,5000)","side==0&&strip==0");
c1->Draw();
// Out:
// <div id="root_plot_1782884210638" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782884210638() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(31101,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782884210638', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e>>(5000,0,5000)","side==0&&strip==1");
c1->Draw();
// Out:
// <div id="root_plot_1782884220471" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1782884220471() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(30915,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1782884220471', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("strip>>(32,0,32)","side==0 && e>50");
c1->Draw();
// Out:
// <div id="root_plot_1783084991810" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783084991810() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21759,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783084991810', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("strip>>(32,0,32)","side==1&&e>50");
c1->Draw();
// Out:
// <div id="root_plot_1783085063997" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783085063997() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21760,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783085063997', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...
