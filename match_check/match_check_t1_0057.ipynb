// %%
TChain *chain_t0d1 = new TChain("tree");
TChain *chain_t0d2 = new TChain("tree");
TChain *chain_t0d3 = new TChain("tree");
TChain *chain_t0d4 = new TChain("tree");
// TChain *chain_t0s = new TChain("tree");
// TChain *chain_csi = new TChain("tree");
// TChain *chain_beam = new TChain("tree");
 
for (int i = 57; i < 68; i++){
       if (i == 63) continue;
    cout << "Add run: " << i << endl;
    chain_t0d1->Add(Form("/data/disk1/ribll2026_www_data/match/t0d1_t1_%04d.root", i));
    chain_t0d2->Add(Form("/data/disk1/ribll2026_www_data/match/t0d2_t1_%04d.root", i));
    chain_t0d3->Add(Form("/data/disk1/ribll2026_www_data/match/t0d3_t1_%04d.root", i));
    chain_t0d4->Add(Form("/data/disk1/ribll2026_www_data/match/t0d4_t1_%04d.root", i));
}

 // 添加朋友关系
chain_t0d1->AddFriend(chain_t0d2, "d2");
chain_t0d1->AddFriend(chain_t0d3, "d3");
chain_t0d1->AddFriend(chain_t0d4, "d4");
// Out:
// Add run: 57
// Add run: 58
// Add run: 59
// Add run: 60
// Add run: 61
// Add run: 62
// Add run: 64
// Add run: 65
// Add run: 66
// Add run: 67

// %%
tree->Draw("fs:bs>>(32, 0, 32, 32, 0, 32)","","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783327419702" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783327419702() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(27456,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783327419702', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("d2.fs:d2.bs>>(64, 0, 64, 64, 0, 64)","","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783327466483" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783327466483() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(36514,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783327466483', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("d3.fs:d3.bs>>(32, 0, 32, 32, 0, 32)","","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783327634656" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783327634656() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(27542,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783327634656', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("d4.fs:d4.bs>>(32, 0, 32, 32, 0, 32)","","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783327817133" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783327817133() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(27684,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783327817133', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e.[0]:d2.e[0]>>(2000,0,70000,2000,0,70000)","","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783327238232" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783327238232() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(1285679,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783327238232', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e.[0]:d2.e[0]>>(700,0,70000,700,0,70000)","num==2&&d2.num==2","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783326415196" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783326415196() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(103026,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783326415196', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("e.[0]:d2.e[0]>>(700,0,70000,700,0,70000)","num==1&&d2.num==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783326737273" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783326737273() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(264823,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783326737273', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("d2.e[0]:d3.e[0]>>(700,0,70000,700,0,70000)","d3.num==2&&d2.num==2","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783326544273" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783326544273() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(118917,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783326544273', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("d2.e[0]:d3.e[0]>>(700,0,70000,700,0,70000)","d3.num==1&&d2.num==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783326593316" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783326593316() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(337143,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783326593316', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("d2.e[0]:d3.e[0]>>(1000,0,70000,1000,0,70000)","","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783327855576" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783327855576() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(692102,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783327855576', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("d3.e[0]:d4.e[0]>>(1000,0,70000,1000,0,70000)","","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783327870884" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783327870884() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(304142,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783327870884', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...
