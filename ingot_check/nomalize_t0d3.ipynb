// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/normalize/t0d3_t1_0060_0060.root");
TFile *opt = new TFile("/home/ribll2026/ribll2026_www/github_code/jupyter/ingot_check/root_file/normalize_t0d3.root","recreate");

TGraph *gf[32];
TH1D *resf[32];
TGraph *gb[32];
TH1D *resb[32];

for (int i = 0; i < 32; i++) {
    // 创建 canvas，只在循环内使用，不删除
    TCanvas *c1 = new TCanvas(Form("c1_%d",i), Form("front_back_%d",i), 1000, 500);
    TCanvas *c2 = new TCanvas(Form("c2_%d",i), Form("front_back_%d",i), 1000, 500);
    c1->Divide(2,1);
    c2->Divide(2,1);

    // 直接从文件读取（不需要先 new）
    gf[i] = (TGraph*)f->Get(Form("gf%d",i));
    resf[i] = (TH1D*)f->Get(Form("resf%d",i));
    
    // 检查是否读取成功
    if (!gf[i] || !resf[i]) {
        cout << "Warning: Cannot find gf" << i << " or resf" << i << endl;
        continue;
    }
    
    c1->cd(1);
    gf[i]->SetTitle(Form("front strip %d",i));
    gf[i]->Draw("AP*");
    c1->cd(2);
    resf[i]->Draw();

    gb[i] = (TGraph*)f->Get(Form("gb%d",i));
    resb[i] = (TH1D*)f->Get(Form("resb%d",i));
    
    if (!gb[i] || !resb[i]) {
        cout << "Warning: Cannot find gb" << i << " or resb" << i << endl;
        continue;
    }
    
    c2->cd(1);
    gb[i]->SetTitle(Form("back strip %d",i));
    gb[i]->Draw("AP*");
    c2->cd(2);
    resb[i]->Draw();

    // 写入 canvas 到文件
    opt->cd();  // 切换到输出文件
    c1->Write(Form("front%02d",i));
    c2->Write(Form("back%02d",i));
    
    // 删除 canvas（注意：不要删除从 f 读取的对象）
    delete c1;
    delete c2;
}

opt->Close();
// f->Close();  // 记得关闭输入文件

// %%
TCanvas *c1 = new TCanvas("c1","c1",800,400);
c1->Divide(2,1);
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

// %%
// read TGraph from file
// c1->Clear();
TGraph *gf0 = (TGraph*)f->Get("gf0");
TH1F *resf0 = (TH1F*)f->Get("resf0");
gf0->SetTitle("front strip 0");
c1->cd(1);
gf0->Draw("AP*");
c1->cd(2);
resf0->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254475180" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254475180() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(34059,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254475180', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 1 的数据

TGraph *gf1 = (TGraph*)f->Get("gf1");
TH1F *resf1 = (TH1F*)f->Get("resf1");
gf1->SetTitle("front strip 1");
c1->cd(1);
gf1->Draw("AP*");
c1->cd(2);
resf1->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254475385" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254475385() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(34452,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254475385', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 2 的数据

TGraph *gf2 = (TGraph*)f->Get("gf2");
TH1F *resf2 = (TH1F*)f->Get("resf2");
gf2->SetTitle("front strip 2");
c1->cd(1);
gf2->Draw("AP*");
c1->cd(2);
resf2->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254475590" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254475590() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(35228,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254475590', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 3 的数据

TGraph *gf3 = (TGraph*)f->Get("gf3");
TH1F *resf3 = (TH1F*)f->Get("resf3");
gf3->SetTitle("front strip 3");
c1->cd(1);
gf3->Draw("AP*");
c1->cd(2);
resf3->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254475795" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254475795() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(35674,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254475795', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 4 的数据

TGraph *gf4 = (TGraph*)f->Get("gf4");
TH1F *resf4 = (TH1F*)f->Get("resf4");
gf4->SetTitle("front strip 4");
c1->cd(1);
gf4->Draw("AP*");
c1->cd(2);
resf4->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254476000" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254476000() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(35760,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254476000', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 5 的数据

TGraph *gf5 = (TGraph*)f->Get("gf5");
TH1F *resf5 = (TH1F*)f->Get("resf5");
gf5->SetTitle("front strip 5");
c1->cd(1);
gf5->Draw("AP*");
c1->cd(2);
resf5->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254476207" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254476207() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(37160,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254476207', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 6 的数据

TGraph *gf6 = (TGraph*)f->Get("gf6");
TH1F *resf6 = (TH1F*)f->Get("resf6");
gf6->SetTitle("front strip 6");
c1->cd(1);
gf6->Draw("AP*");
c1->cd(2);
resf6->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254476411" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254476411() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(37670,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254476411', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 7 的数据

TGraph *gf7 = (TGraph*)f->Get("gf7");
TH1F *resf7 = (TH1F*)f->Get("resf7");
gf7->SetTitle("front strip 7");
c1->cd(1);
gf7->Draw("AP*");
c1->cd(2);
resf7->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254476616" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254476616() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(37993,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254476616', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 8 的数据

TGraph *gf8 = (TGraph*)f->Get("gf8");
TH1F *resf8 = (TH1F*)f->Get("resf8");
gf8->SetTitle("front strip 8");
c1->cd(1);
gf8->Draw("AP*");
c1->cd(2);
resf8->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254476822" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254476822() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(39281,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254476822', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 9 的数据

TGraph *gf9 = (TGraph*)f->Get("gf9");
TH1F *resf9 = (TH1F*)f->Get("resf9");
gf9->SetTitle("front strip 9");
c1->cd(1);
gf9->Draw("AP*");
c1->cd(2);
resf9->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254477026" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254477026() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(41847,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254477026', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 10 的数据

TGraph *gf10 = (TGraph*)f->Get("gf10");
TH1F *resf10 = (TH1F*)f->Get("resf10");
gf10->SetTitle("front strip 10");
c1->cd(1);
gf10->Draw("AP*");
c1->cd(2);
resf10->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254477231" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254477231() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(44996,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254477231', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 11 的数据

TGraph *gf11 = (TGraph*)f->Get("gf11");
TH1F *resf11 = (TH1F*)f->Get("resf11");
gf11->SetTitle("front strip 11");
c1->cd(1);
gf11->Draw("AP*");
c1->cd(2);
resf11->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254477436" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254477436() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(46333,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254477436', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 12 的数据

TGraph *gf12 = (TGraph*)f->Get("gf12");
TH1F *resf12 = (TH1F*)f->Get("resf12");
gf12->SetTitle("front strip 12");
c1->cd(1);
gf12->Draw("AP*");
c1->cd(2);
resf12->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254477641" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254477641() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(47570,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254477641', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 13 的数据

TGraph *gf13 = (TGraph*)f->Get("gf13");
TH1F *resf13 = (TH1F*)f->Get("resf13");
gf13->SetTitle("front strip 13");
c1->cd(1);
gf13->Draw("AP*");
c1->cd(2);
resf13->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254477846" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254477846() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(46783,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254477846', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 14 的数据

TGraph *gf14 = (TGraph*)f->Get("gf14");
TH1F *resf14 = (TH1F*)f->Get("resf14");
gf14->SetTitle("front strip 14");
c1->cd(1);
gf14->Draw("AP*");
c1->cd(2);
resf14->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254478050" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254478050() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(47343,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254478050', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 15 的数据

TGraph *gf15 = (TGraph*)f->Get("gf15");
TH1F *resf15 = (TH1F*)f->Get("resf15");
gf15->SetTitle("front strip 15");
c1->cd(1);
gf15->Draw("AP*");
c1->cd(2);
resf15->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254478255" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254478255() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(48744,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254478255', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 16 的数据

TGraph *gf16 = (TGraph*)f->Get("gf16");
TH1F *resf16 = (TH1F*)f->Get("resf16");
gf16->SetTitle("front strip 16");
c1->cd(1);
gf16->Draw("AP*");
c1->cd(2);
resf16->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254478461" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254478461() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(50226,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254478461', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 17 的数据

TGraph *gf17 = (TGraph*)f->Get("gf17");
TH1F *resf17 = (TH1F*)f->Get("resf17");
gf17->SetTitle("front strip 17");
c1->cd(1);
gf17->Draw("AP*");
c1->cd(2);
resf17->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254478666" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254478666() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(49440,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254478666', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 18 的数据

TGraph *gf18 = (TGraph*)f->Get("gf18");
TH1F *resf18 = (TH1F*)f->Get("resf18");
gf18->SetTitle("front strip 18");
c1->cd(1);
gf18->Draw("AP*");
c1->cd(2);
resf18->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254478871" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254478871() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(47879,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254478871', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 19 的数据

TGraph *gf19 = (TGraph*)f->Get("gf19");
TH1F *resf19 = (TH1F*)f->Get("resf19");
gf19->SetTitle("front strip 19");
c1->cd(1);
gf19->Draw("AP*");
c1->cd(2);
resf19->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254479077" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254479077() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(46432,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254479077', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 20 的数据

TGraph *gf20 = (TGraph*)f->Get("gf20");
TH1F *resf20 = (TH1F*)f->Get("resf20");
gf20->SetTitle("front strip 20");
c1->cd(1);
gf20->Draw("AP*");
c1->cd(2);
resf20->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254479282" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254479282() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(45680,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254479282', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 21 的数据

TGraph *gf21 = (TGraph*)f->Get("gf21");
TH1F *resf21 = (TH1F*)f->Get("resf21");
gf21->SetTitle("front strip 21");
c1->cd(1);
gf21->Draw("AP*");
c1->cd(2);
resf21->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254479487" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254479487() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(44849,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254479487', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 22 的数据

TGraph *gf22 = (TGraph*)f->Get("gf22");
TH1F *resf22 = (TH1F*)f->Get("resf22");
gf22->SetTitle("front strip 22");
c1->cd(1);
gf22->Draw("AP*");
c1->cd(2);
resf22->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254479692" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254479692() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(41778,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254479692', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 23 的数据

TGraph *gf23 = (TGraph*)f->Get("gf23");
TH1F *resf23 = (TH1F*)f->Get("resf23");
gf23->SetTitle("front strip 23");
c1->cd(1);
gf23->Draw("AP*");
c1->cd(2);
resf23->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254479898" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254479898() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(40548,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254479898', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 24 的数据

TGraph *gf24 = (TGraph*)f->Get("gf24");
TH1F *resf24 = (TH1F*)f->Get("resf24");
gf24->SetTitle("front strip 24");
c1->cd(1);
gf24->Draw("AP*");
c1->cd(2);
resf24->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254480103" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254480103() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(38251,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254480103', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 25 的数据

TGraph *gf25 = (TGraph*)f->Get("gf25");
TH1F *resf25 = (TH1F*)f->Get("resf25");
gf25->SetTitle("front strip 25");
c1->cd(1);
gf25->Draw("AP*");
c1->cd(2);
resf25->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254480309" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254480309() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(36921,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254480309', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 26 的数据

TGraph *gf26 = (TGraph*)f->Get("gf26");
TH1F *resf26 = (TH1F*)f->Get("resf26");
gf26->SetTitle("front strip 26");
c1->cd(1);
gf26->Draw("AP*");
c1->cd(2);
resf26->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254480512" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254480512() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(36367,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254480512', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 27 的数据

TGraph *gf27 = (TGraph*)f->Get("gf27");
TH1F *resf27 = (TH1F*)f->Get("resf27");
gf27->SetTitle("front strip 27");
c1->cd(1);
gf27->Draw("AP*");
c1->cd(2);
resf27->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254480717" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254480717() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(36282,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254480717', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 28 的数据

TGraph *gf28 = (TGraph*)f->Get("gf28");
TH1F *resf28 = (TH1F*)f->Get("resf28");
gf28->SetTitle("front strip 28");
c1->cd(1);
gf28->Draw("AP*");
c1->cd(2);
resf28->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254480922" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254480922() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33094,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254480922', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 29 的数据

TGraph *gf29 = (TGraph*)f->Get("gf29");
TH1F *resf29 = (TH1F*)f->Get("resf29");
gf29->SetTitle("front strip 29");
c1->cd(1);
gf29->Draw("AP*");
c1->cd(2);
resf29->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254481126" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254481126() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(32991,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254481126', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 30 的数据

TGraph *gf30 = (TGraph*)f->Get("gf30");
TH1F *resf30 = (TH1F*)f->Get("resf30");
gf30->SetTitle("front strip 30");
c1->cd(1);
gf30->Draw("AP*");
c1->cd(2);
resf30->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254481331" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254481331() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(32740,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254481331', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 front strip 31 的数据

TGraph *gf31 = (TGraph*)f->Get("gf31");
TH1F *resf31 = (TH1F*)f->Get("resf31");
gf31->SetTitle("front strip 31");
c1->cd(1);
gf31->Draw("AP*");
c1->cd(2);
resf31->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254481534" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254481534() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(32843,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254481534', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 0 的数据

TGraph *gb0 = (TGraph*)f->Get("gb0");
TH1F *resb0 = (TH1F*)f->Get("resb0");
gb0->SetTitle("back strip 0");
c1->cd(1);
gb0->Draw("AP*");
c1->cd(2);
resb0->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254481738" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254481738() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(32841,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254481738', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 1 的数据

TGraph *gb1 = (TGraph*)f->Get("gb1");
TH1F *resb1 = (TH1F*)f->Get("resb1");
gb1->SetTitle("back strip 1");
c1->cd(1);
gb1->Draw("AP*");
c1->cd(2);
resb1->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254481943" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254481943() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(32735,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254481943', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 2 的数据

TGraph *gb2 = (TGraph*)f->Get("gb2");
TH1F *resb2 = (TH1F*)f->Get("resb2");
gb2->SetTitle("back strip 2");
c1->cd(1);
gb2->Draw("AP*");
c1->cd(2);
resb2->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254482147" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254482147() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33106,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254482147', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 3 的数据

TGraph *gb3 = (TGraph*)f->Get("gb3");
TH1F *resb3 = (TH1F*)f->Get("resb3");
gb3->SetTitle("back strip 3");
c1->cd(1);
gb3->Draw("AP*");
c1->cd(2);
resb3->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254482352" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254482352() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33051,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254482352', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 4 的数据

TGraph *gb4 = (TGraph*)f->Get("gb4");
TH1F *resb4 = (TH1F*)f->Get("resb4");
gb4->SetTitle("back strip 4");
c1->cd(1);
gb4->Draw("AP*");
c1->cd(2);
resb4->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254482557" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254482557() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33315,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254482557', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 5 的数据

TGraph *gb5 = (TGraph*)f->Get("gb5");
TH1F *resb5 = (TH1F*)f->Get("resb5");
gb5->SetTitle("back strip 5");
c1->cd(1);
gb5->Draw("AP*");
c1->cd(2);
resb5->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254482761" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254482761() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33489,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254482761', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 6 的数据

TGraph *gb6 = (TGraph*)f->Get("gb6");
TH1F *resb6 = (TH1F*)f->Get("resb6");
gb6->SetTitle("back strip 6");
c1->cd(1);
gb6->Draw("AP*");
c1->cd(2);
resb6->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254482967" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254482967() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33377,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254482967', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 7 的数据

TGraph *gb7 = (TGraph*)f->Get("gb7");
TH1F *resb7 = (TH1F*)f->Get("resb7");
gb7->SetTitle("back strip 7");
c1->cd(1);
gb7->Draw("AP*");
c1->cd(2);
resb7->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254483172" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254483172() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33695,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254483172', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 8 的数据

TGraph *gb8 = (TGraph*)f->Get("gb8");
TH1F *resb8 = (TH1F*)f->Get("resb8");
gb8->SetTitle("back strip 8");
c1->cd(1);
gb8->Draw("AP*");
c1->cd(2);
resb8->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254483377" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254483377() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(34084,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254483377', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 9 的数据

TGraph *gb9 = (TGraph*)f->Get("gb9");
TH1F *resb9 = (TH1F*)f->Get("resb9");
gb9->SetTitle("back strip 9");
c1->cd(1);
gb9->Draw("AP*");
c1->cd(2);
resb9->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254483582" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254483582() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(34899,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254483582', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 10 的数据

TGraph *gb10 = (TGraph*)f->Get("gb10");
TH1F *resb10 = (TH1F*)f->Get("resb10");
gb10->SetTitle("back strip 10");
c1->cd(1);
gb10->Draw("AP*");
c1->cd(2);
resb10->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254483787" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254483787() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(34944,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254483787', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 11 的数据

TGraph *gb11 = (TGraph*)f->Get("gb11");
TH1F *resb11 = (TH1F*)f->Get("resb11");
gb11->SetTitle("back strip 11");
c1->cd(1);
gb11->Draw("AP*");
c1->cd(2);
resb11->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254483992" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254483992() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(36056,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254483992', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 12 的数据

TGraph *gb12 = (TGraph*)f->Get("gb12");
TH1F *resb12 = (TH1F*)f->Get("resb12");
gb12->SetTitle("back strip 12");
c1->cd(1);
gb12->Draw("AP*");
c1->cd(2);
resb12->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254484198" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254484198() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(38521,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254484198', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 13 的数据

TGraph *gb13 = (TGraph*)f->Get("gb13");
TH1F *resb13 = (TH1F*)f->Get("resb13");
gb13->SetTitle("back strip 13");
c1->cd(1);
gb13->Draw("AP*");
c1->cd(2);
resb13->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254484404" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254484404() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(40520,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254484404', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 14 的数据

TGraph *gb14 = (TGraph*)f->Get("gb14");
TH1F *resb14 = (TH1F*)f->Get("resb14");
gb14->SetTitle("back strip 14");
c1->cd(1);
gb14->Draw("AP*");
c1->cd(2);
resb14->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254484609" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254484609() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(42348,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254484609', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 15 的数据

TGraph *gb15 = (TGraph*)f->Get("gb15");
TH1F *resb15 = (TH1F*)f->Get("resb15");
gb15->SetTitle("back strip 15");
c1->cd(1);
gb15->Draw("AP*");
c1->cd(2);
resb15->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254484814" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254484814() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(43455,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254484814', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 16 的数据

TGraph *gb16 = (TGraph*)f->Get("gb16");
TH1F *resb16 = (TH1F*)f->Get("resb16");
gb16->SetTitle("back strip 16");
c1->cd(1);
gb16->Draw("AP*");
c1->cd(2);
resb16->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254485020" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254485020() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(45087,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254485020', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 17 的数据

TGraph *gb17 = (TGraph*)f->Get("gb17");
TH1F *resb17 = (TH1F*)f->Get("resb17");
gb17->SetTitle("back strip 17");
c1->cd(1);
gb17->Draw("AP*");
c1->cd(2);
resb17->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254485224" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254485224() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(46078,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254485224', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 18 的数据

TGraph *gb18 = (TGraph*)f->Get("gb18");
TH1F *resb18 = (TH1F*)f->Get("resb18");
gb18->SetTitle("back strip 18");
c1->cd(1);
gb18->Draw("AP*");
c1->cd(2);
resb18->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254485429" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254485429() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(35085,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254485429', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 19 的数据

TGraph *gb19 = (TGraph*)f->Get("gb19");
TH1F *resb19 = (TH1F*)f->Get("resb19");
gb19->SetTitle("back strip 19");
c1->cd(1);
gb19->Draw("AP*");
c1->cd(2);
resb19->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254485636" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254485636() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(35726,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254485636', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 20 的数据

TGraph *gb20 = (TGraph*)f->Get("gb20");
TH1F *resb20 = (TH1F*)f->Get("resb20");
gb20->SetTitle("back strip 20");
c1->cd(1);
gb20->Draw("AP*");
c1->cd(2);
resb20->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254485840" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254485840() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(41524,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254485840', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 21 的数据

TGraph *gb21 = (TGraph*)f->Get("gb21");
TH1F *resb21 = (TH1F*)f->Get("resb21");
gb21->SetTitle("back strip 21");
c1->cd(1);
gb21->Draw("AP*");
c1->cd(2);
resb21->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254486045" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254486045() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(39281,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254486045', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 22 的数据

TGraph *gb22 = (TGraph*)f->Get("gb22");
TH1F *resb22 = (TH1F*)f->Get("resb22");
gb22->SetTitle("back strip 22");
c1->cd(1);
gb22->Draw("AP*");
c1->cd(2);
resb22->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254486250" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254486250() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(36714,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254486250', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 23 的数据

TGraph *gb23 = (TGraph*)f->Get("gb23");
TH1F *resb23 = (TH1F*)f->Get("resb23");
gb23->SetTitle("back strip 23");
c1->cd(1);
gb23->Draw("AP*");
c1->cd(2);
resb23->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254486455" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254486455() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(35841,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254486455', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 24 的数据

TGraph *gb24 = (TGraph*)f->Get("gb24");
TH1F *resb24 = (TH1F*)f->Get("resb24");
gb24->SetTitle("back strip 24");
c1->cd(1);
gb24->Draw("AP*");
c1->cd(2);
resb24->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254486659" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254486659() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(34706,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254486659', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 25 的数据

TGraph *gb25 = (TGraph*)f->Get("gb25");
TH1F *resb25 = (TH1F*)f->Get("resb25");
gb25->SetTitle("back strip 25");
c1->cd(1);
gb25->Draw("AP*");
c1->cd(2);
resb25->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254486864" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254486864() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33936,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254486864', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 26 的数据

TGraph *gb26 = (TGraph*)f->Get("gb26");
TH1F *resb26 = (TH1F*)f->Get("resb26");
gb26->SetTitle("back strip 26");
c1->cd(1);
gb26->Draw("AP*");
c1->cd(2);
resb26->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254487069" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254487069() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33927,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254487069', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 27 的数据

TGraph *gb27 = (TGraph*)f->Get("gb27");
TH1F *resb27 = (TH1F*)f->Get("resb27");
gb27->SetTitle("back strip 27");
c1->cd(1);
gb27->Draw("AP*");
c1->cd(2);
resb27->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254487274" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254487274() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33861,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254487274', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 28 的数据

TGraph *gb28 = (TGraph*)f->Get("gb28");
TH1F *resb28 = (TH1F*)f->Get("resb28");
gb28->SetTitle("back strip 28");
c1->cd(1);
gb28->Draw("AP*");
c1->cd(2);
resb28->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254487479" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254487479() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33973,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254487479', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 29 的数据

TGraph *gb29 = (TGraph*)f->Get("gb29");
TH1F *resb29 = (TH1F*)f->Get("resb29");
gb29->SetTitle("back strip 29");
c1->cd(1);
gb29->Draw("AP*");
c1->cd(2);
resb29->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254487684" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254487684() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33442,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254487684', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 30 的数据

TGraph *gb30 = (TGraph*)f->Get("gb30");
TH1F *resb30 = (TH1F*)f->Get("resb30");
gb30->SetTitle("back strip 30");
c1->cd(1);
gb30->Draw("AP*");
c1->cd(2);
resb30->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254487889" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254487889() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33189,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254487889', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// 读取 back strip 31 的数据

TGraph *gb31 = (TGraph*)f->Get("gb31");
TH1F *resb31 = (TH1F*)f->Get("resb31");
gb31->SetTitle("back strip 31");
c1->cd(1);
gb31->Draw("AP*");
c1->cd(2);
resb31->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1783254488093" style="width: 800px; height: 400px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783254488093() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33089,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783254488093', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
// f->Close();  // 记得关闭输入文件
