// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/ingot/t0d2_t1_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : forged t0d2                                            *
// *Entries :   109133 : Total =         8961570 bytes  File  Size =    3887787 *
// *        :          : Tree compression factor =   2.31                       *
// ******************************************************************************
// *Br    0 :front_num : fn/I                                                   *
// *Entries :   109133 : Total  Size=     438176 bytes  File Size  =      66179 *
// *Baskets :       14 : Basket Size=      32000 bytes  Compression=   6.61     *
// *............................................................................*
// *Br    1 :front_strip : fs[fn]/I                                             *
// *Entries :   109133 : Total  Size=     851556 bytes  File Size  =     274184 *
// *Baskets :       41 : Basket Size=      32000 bytes  Compression=   3.10     *
// ...

// %%
tree->Draw("fn:bn>>(32,0,32,32,0,32)","fn>0&&bn>0","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250856567" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250856567() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(23680,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250856567', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("fe[0]:be[0]>>(1000,0,70000,1000,0,70000)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250856774" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250856774() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(106272,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250856774', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("fe[0]:be[0]>>(1000,0,70000,1000,0,70000)","fn==1&&bn==1&&fs==17","box");
c1->Draw();
// Out:
// <div id="root_plot_1783307890529" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783307890529() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(23088,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783307890529', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("fs[0]>>(64, 0, 64)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783255770188" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783255770188() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21779,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783255770188', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("bs[0]>>(64, 0, 64)","fn==1&&bn==1&&fs==31","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783255811910" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783255811910() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21718,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783255811910', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("fs[0]>>(64, 0, 64)","fn==1&&bn==1&&bs>30&&bs<46","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783255956976" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783255956976() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21783,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783255956976', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("bs[0]>>(64, 0, 64)","fn==1&&bn==1&&fs>20&&fs<40","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783256057979" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783256057979() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21800,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783256057979', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("fs[0]>>(64, 0, 64)","fn==1&&bn==1&&bs>10&&bs<50","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783256329857" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783256329857() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(21804,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783256329857', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("fs[0]:bs[0]>>(64,0,64,64,0,64)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250857213" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250857213() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(32021,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250857213', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250857422" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250857422() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(261857,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250857422', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250857624" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250857624() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(97210,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250857624', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250857832" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250857832() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(277118,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250857832', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250858033" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250858033() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(107099,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250858033', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...
