// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/ingot/t0d2_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : forged t0d2                                            *
// *Entries : 26426630 : Total =      2761975774 bytes  File  Size = 1158675823 *
// *        :          : Tree compression factor =   2.38                       *
// ******************************************************************************
// *Br    0 :front_num : fn/I                                                   *
// *Entries : 26426630 : Total  Size=  105726308 bytes  File Size  =    6892006 *
// *Baskets :      203 : Basket Size=     970240 bytes  Compression=  15.34     *
// *............................................................................*
// *Br    1 :front_strip : fs[fn]/I                                             *
// *Entries : 26426630 : Total  Size=  313466934 bytes  File Size  =   82911265 *
// *Baskets :      394 : Basket Size=    7868928 bytes  Compression=   3.78     *
// *............................................................................*
// *Br    2 :front_energy : fe[fn]/D                                            *
// *Entries : 26426630 : Total  Size=  521202098 bytes  File Size  =  222262243 *
// *Baskets :      548 : Basket Size=    9798144 bytes  Compression=   2.34     *
// *............................................................................*
// *Br    3 :front_time : ft[fn]/D                                              *
// *Entries : 26426630 : Total  Size=  521201000 bytes  File Size  =  292487985 *
// *Baskets :      548 : Basket Size=    9797632 bytes  Compression=   1.78     *
// *............................................................................*
// *Br    4 :back_num  : bn/I                                                   *
// *Entries : 26426630 : Total  Size=  105726104 bytes  File Size  =   15228753 *
// *Baskets :      203 : Basket Size=     970240 bytes  Compression=   6.94     *
// *............................................................................*
// *Br    5 :back_strip : bs[bn]/I                                              *
// *Entries : 26426630 : Total  Size=  281223459 bytes  File Size  =   85691497 *
// *Baskets :      370 : Basket Size=    7575040 bytes  Compression=   3.28     *
// *............................................................................*
// *Br    6 :back_energy : be[bn]/D                                             *
// *Entries : 26426630 : Total  Size=  456715447 bytes  File Size  =  188621399 *
// *Baskets :      501 : Basket Size=    9210880 bytes  Compression=   2.42     *
// *............................................................................*
// *Br    7 :back_time : bt[bn]/D                                               *
// *Entries : 26426630 : Total  Size=  456714443 bytes  File Size  =  264548279 *
// *Baskets :      501 : Basket Size=    9210880 bytes  Compression=   1.73     *
// *............................................................................*

// %%
tree->Draw("fn:bn>>(32,0,32,32,0,32)","fn>0&&bn>0","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145183530" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145183530() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(24125,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145183530', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145183530();
// </script>
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %%
tree->Draw("fe[0]:be[0]>>(1000,0,70000,1000,0,70000)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145189391" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145189391() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(452805,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145189391', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145189391();
// </script>

// %%
tree->Draw("fs[0]:bs[0]>>(64,0,64,64,0,64)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145193131" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145193131() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33084,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145193131', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145193131();
// </script>

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145200172" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145200172() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(1310281,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145200172', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145200172();
// </script>

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145206417" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145206417() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(636727,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145206417', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145206417();
// </script>

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145211762" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145211762() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(1107650,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145211762', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145211762();
// </script>

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145216997" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145216997() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(824693,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145216997', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145216997();
// </script>
