// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/ingot/t0d1_t1_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : forged t0d1                                            *
// *Entries :   109133 : Total =         8309282 bytes  File  Size =    3545416 *
// *        :          : Tree compression factor =   2.34                       *
// ******************************************************************************
// *Br    0 :front_num : fn/I                                                   *
// *Entries :   109133 : Total  Size=     438176 bytes  File Size  =      70693 *
// *Baskets :       14 : Basket Size=      32000 bytes  Compression=   6.19     *
// *............................................................................*
// *Br    1 :front_strip : fs[fn]/I                                             *
// *Entries :   109133 : Total  Size=     970690 bytes  File Size  =     314932 *
// *Baskets :       44 : Basket Size=      32000 bytes  Compression=   3.08     *
// *............................................................................*
// *Br    2 :front_energy : fe[fn]/D                                            *
// *Entries :   109133 : Total  Size=    1501689 bytes  File Size  =     598846 *
// *Baskets :       61 : Basket Size=      32000 bytes  Compression=   2.50     *
// *............................................................................*
// *Br    3 :front_time : ft[fn]/D                                              *
// *Entries :   109133 : Total  Size=    1501565 bytes  File Size  =     906073 *
// *Baskets :       61 : Basket Size=      32000 bytes  Compression=   1.66     *
// *............................................................................*
// *Br    4 :back_num  : bn/I                                                   *
// *Entries :   109133 : Total  Size=     438161 bytes  File Size  =      66302 *
// *Baskets :       14 : Basket Size=      32000 bytes  Compression=   6.60     *
// *............................................................................*
// *Br    5 :back_strip : bs[bn]/I                                              *
// *Entries :   109133 : Total  Size=     867694 bytes  File Size  =     270174 *
// *Baskets :       41 : Basket Size=      32000 bytes  Compression=   3.21     *
// *............................................................................*
// *Br    6 :back_energy : be[bn]/D                                             *
// *Entries :   109133 : Total  Size=    1295719 bytes  File Size  =     534922 *
// *Baskets :       55 : Basket Size=      32000 bytes  Compression=   2.42     *
// *............................................................................*
// *Br    7 :back_time : bt[bn]/D                                               *
// *Entries :   109133 : Total  Size=    1295607 bytes  File Size  =     779283 *
// *Baskets :       55 : Basket Size=      32000 bytes  Compression=   1.66     *
// *............................................................................*

// %%
tree->Draw("fn:bn>>(32,0,32,32,0,32)","fn>0&&bn>0","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783237208706" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783237208706() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(25137,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783237208706', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783237208706();
// </script>

// %%
tree->Draw("fe[0]:be[0]>>(1000,0,70000,1000,0,70000)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783237208915" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783237208915() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(184240,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783237208915', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783237208915();
// </script>

// %%
tree->Draw("fe[0]:be[0]>>(1000,0,70000,1000,0,70000)","fn==1&&bn==1&&fs==5","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783239514383" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783239514383() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(24527,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783239514383', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783239514383();
// </script>

// %%
tree->Draw("fe[0]:be[0]>>(700,0,70000,700,0,70000)","fn==1&&bn==1&&fs==10&&bs==15","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783239614774" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783239614774() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(26311,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783239614774', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783239614774();
// </script>

// %%
tree->Draw("fs[0]:bs[0]>>(32,0,32,32,0,32)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783237209116" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783237209116() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(25896,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783237209116', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783237209116();
// </script>

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783237209322" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783237209322() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(67429,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783237209322', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783237209322();
// </script>

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783237209528" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783237209528() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(125841,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783237209528', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783237209528();
// </script>

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783237209732" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783237209732() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(66512,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783237209732', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783237209732();
// </script>

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783237209939" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783237209939() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(179618,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783237209939', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783237209939();
// </script>
