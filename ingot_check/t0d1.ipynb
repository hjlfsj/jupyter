// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/ingot/t0d1_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : forged t0d1                                            *
// *Entries : 26426630 : Total =      2002336402 bytes  File  Size =  759811884 *
// *        :          : Tree compression factor =   2.64                       *
// ******************************************************************************
// *Br    0 :front_num : fn/I                                                   *
// *Entries : 26426630 : Total  Size=  105725924 bytes  File Size  =    9372222 *
// *Baskets :      199 : Basket Size=    1342976 bytes  Compression=  11.28     *
// *............................................................................*
// *Br    1 :front_strip : fs[fn]/I                                             *
// *Entries : 26426630 : Total  Size=  227075596 bytes  File Size  =   60564801 *
// *Baskets :      391 : Basket Size=   25600000 bytes  Compression=   3.75     *
// ...

// %%
tree->Draw("fn:bn>>(32,0,32,32,0,32)","fn>0&&bn>0","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783142610574" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783142610574() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(25432,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783142610574', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
tree->Draw("fe:be>>(1000,0,50000,1000,0,50000)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783142682599" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783142682599() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(1071158,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783142682599', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...
