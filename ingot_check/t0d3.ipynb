// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/ingot/t0d3_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : forged t0d3                                            *
// *Entries : 26426630 : Total =      2226321760 bytes  File  Size =  897602621 *
// *        :          : Tree compression factor =   2.48                       *
// ******************************************************************************
// *Br    0 :front_num : fn/I                                                   *
// *Entries : 26426630 : Total  Size=  105725732 bytes  File Size  =   11547215 *
// *Baskets :      197 : Basket Size=    1202688 bytes  Compression=   9.16     *
// *............................................................................*
// *Br    1 :front_strip : fs[fn]/I                                             *
// *Entries : 26426630 : Total  Size=  235323238 bytes  File Size  =   63366197 *
// *Baskets :      384 : Basket Size=    8971776 bytes  Compression=   3.71     *
// *............................................................................*
// *Br    2 :front_energy : fe[fn]/D                                            *
// *Entries : 26426630 : Total  Size=  364908908 bytes  File Size  =  145377541 *
// *Baskets :      474 : Basket Size=   25600000 bytes  Compression=   2.51     *
// *............................................................................*
// *Br    3 :front_time : ft[fn]/D                                              *
// *Entries : 26426630 : Total  Size=  364907958 bytes  File Size  =  205730762 *
// *Baskets :      474 : Basket Size=   25600000 bytes  Compression=   1.77     *
// *............................................................................*
// *Br    4 :back_num  : bn/I                                                   *
// *Entries : 26426630 : Total  Size=  105725534 bytes  File Size  =   13581845 *
// *Baskets :      197 : Basket Size=    1202688 bytes  Compression=   7.78     *
// *............................................................................*
// *Br    5 :back_strip : bs[bn]/I                                              *
// *Entries : 26426630 : Total  Size=  252241181 bytes  File Size  =   66608268 *
// *Baskets :      400 : Basket Size=    9164288 bytes  Compression=   3.79     *
// *............................................................................*
// *Br    6 :back_energy : be[bn]/D                                             *
// *Entries : 26426630 : Total  Size=  398745121 bytes  File Size  =  164849015 *
// *Baskets :      506 : Basket Size=   25600000 bytes  Compression=   2.42     *
// *............................................................................*
// *Br    7 :back_time : bt[bn]/D                                               *
// *Entries : 26426630 : Total  Size=  398744107 bytes  File Size  =  226511533 *
// *Baskets :      506 : Basket Size=   25600000 bytes  Compression=   1.76     *
// *............................................................................*

// %%
tree->Draw("fn:bn>>(32,0,32,32,0,32)","fn>0&&bn>0","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145267667" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145267667() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(23995,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145267667', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145267667();
// </script>
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %%
tree->Draw("fe[0]:be[0]>>(1000,0,70000,1000,0,70000)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145276008" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145276008() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(1660316,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145276008', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145276008();
// </script>

// %%
tree->Draw("fs[0]:bs[0]>>(32,0,32,32,0,32)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145281957" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145281957() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(26972,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145281957', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145281957();
// </script>

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145286371" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145286371() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(1141839,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145286371', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145286371();
// </script>

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145290710" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145290710() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(1045743,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145290710', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145290710();
// </script>

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145295739" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145295739() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(1238242,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145295739', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145295739();
// </script>

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783145300606" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783145300606() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(1039195,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783145300606', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783145300606();
// </script>
