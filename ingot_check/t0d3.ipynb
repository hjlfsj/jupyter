// %%
TFile *f = TFile::Open("/data/disk1/ribll2026_www_data/ingot/t0d3_t1_0060.root");
TTree *tree = (TTree*)f->Get("tree");
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : forged t0d3                                            *
// *Entries :   109133 : Total =         9594188 bytes  File  Size =    4051054 *
// *        :          : Tree compression factor =   2.37                       *
// ******************************************************************************
// *Br    0 :front_num : fn/I                                                   *
// *Entries :   109133 : Total  Size=     438176 bytes  File Size  =      75683 *
// *Baskets :       14 : Basket Size=      32000 bytes  Compression=   5.78     *
// *............................................................................*
// *Br    1 :front_strip : fs[fn]/I                                             *
// *Entries :   109133 : Total  Size=    1038668 bytes  File Size  =     326098 *
// *Baskets :       47 : Basket Size=      32000 bytes  Compression=   3.18     *
// *............................................................................*
// *Br    2 :front_energy : fe[fn]/D                                            *
// *Entries :   109133 : Total  Size=    1637437 bytes  File Size  =     654555 *
// *Baskets :       65 : Basket Size=      32000 bytes  Compression=   2.50     *
// *............................................................................*
// *Br    3 :front_time : ft[fn]/D                                              *
// *Entries :   109133 : Total  Size=    1637305 bytes  File Size  =     951883 *
// *Baskets :       65 : Basket Size=      32000 bytes  Compression=   1.72     *
// *............................................................................*
// *Br    4 :back_num  : bn/I                                                   *
// *Entries :   109133 : Total  Size=     438161 bytes  File Size  =      76123 *
// *Baskets :       14 : Basket Size=      32000 bytes  Compression=   5.75     *
// *............................................................................*
// *Br    5 :back_strip : bs[bn]/I                                              *
// *Entries :   109133 : Total  Size=    1056824 bytes  File Size  =     330165 *
// *Baskets :       47 : Basket Size=      32000 bytes  Compression=   3.20     *
// *............................................................................*
// *Br    6 :back_energy : be[bn]/D                                             *
// *Entries :   109133 : Total  Size=    1673885 bytes  File Size  =     670722 *
// *Baskets :       66 : Basket Size=      32000 bytes  Compression=   2.49     *
// *............................................................................*
// *Br    7 :back_time : bt[bn]/D                                               *
// *Entries :   109133 : Total  Size=    1673751 bytes  File Size  =     961296 *
// *Baskets :       66 : Basket Size=      32000 bytes  Compression=   1.74     *
// *............................................................................*

// %%
tree->Draw("fn:bn>>(32,0,32,32,0,32)","fn>0&&bn>0","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250933565" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250933565() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(23621,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250933565', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783250933565();
// </script>

// %%
tree->Draw("fe[0]:be[0]>>(1000,0,70000,1000,0,70000)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250933772" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250933772() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(152861,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250933772', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783250933772();
// </script>

// %%
tree->Draw("fe[0]:be[0]>>(500,0,70000,500,0,70000)","fn==1&&bn==1&&(bs==18||bs==19)","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783252564884" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783252564884() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(50039,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783252564884', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783252564884();
// </script>

// %%
tree->Draw("fs[0]:bs[0]>>(32,0,32,32,0,32)","fn==1&&bn==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250933974" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250933974() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(25786,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250933974', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783250933974();
// </script>

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250934180" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250934180() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(101269,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250934180', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783250934180();
// </script>

// %%
tree->Draw("fe[0]:fe[1]>>(1000,0,50000,1000,0,50000)","fn==2&&abs(fs[0]-fs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250934385" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250934385() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(117418,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250934385', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783250934385();
// </script>

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])==1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250934590" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250934590() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(148192,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250934590', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783250934590();
// </script>

// %%
tree->Draw("be[0]:be[1]>>(1000,0,50000,1000,0,50000)","bn==2&&abs(bs[0]-bs[1])>1","colz");
c1->Draw();
// Out:
// <div id="root_plot_1783250934793" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1783250934793() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(111948,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1783250934793', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.3/', 'https://jsroot.gsi.de/7.10.3/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
//             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
//          else
//             servers.shift();
//          function loadJsroot() {
//             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => drawPlot(JSROOT));
//          }
//          loadJsroot();
//       }
//    }
//    process_root_plot_1783250934793();
// </script>
